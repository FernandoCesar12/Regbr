# %% [markdown]
# # Pegando os links das páginas redirecionadas

# %%
import requests # requisições web
import re
from bs4 import BeautifulSoup

Link = []
i  = 1
while i <= 6:
  try:
    url = 'https://atosoficiais.com.br/anp?q=&types=202&types=203&types=204&types=200&types=201&types=9&page='+str(i)

    header = {'User-Agent': "'Mozilla/5.0'"}
    html = requests.get(url, headers = header)
    bs_obj = BeautifulSoup(html.text,"lxml")
    posicao = bs_obj.find_all("a")
    hrefs = ' '.join([str(elem) for elem in posicao]).split('<span rel="title">')

    for href in hrefs:
        if '<a class="btn btn-lei-lista"' in str(href):
            result = str(href).split('<a class="btn btn-lei-lista" href="')[1].split('">')[0]
            Link.append(result)

    i = i+1

  except:
    print('Url error' + ' ' + url)

# Finalizando a formatação as URL's

append_str = 'https://atosoficiais.com.br'
link_resolucoes = [append_str + sub for sub in Link]  # Adicionando o préfixo

# %% [markdown]
# # Pegando a parte textual

# %%
url_list = link_resolucoes # Entrando com a lista de URL's em interesse

Texto = []
Titulo = []

for url in url_list :
  header = {'User-Agent': "'Mozilla/5.0'"}
  html = requests.get(url, headers = header)
  bs_obj = BeautifulSoup(html.text,"lxml")
  posicao = bs_obj.find_all("div", {"id": "conteudo-principal"})

  hrefs = ' '.join([str(elem) for elem in posicao]).split('\n')

  Resultado = []
  for i in range(0,len(hrefs)): # Separando a parte textual em interesse
    if 'class="text-center"' in hrefs[i]:
      Resul = hrefs[i].split('<center>',1)[1]
      Resultado.append(Resul)

  for i in range(0,len(Resultado)): # Separando o título
   title =  Resultado[i].split('<h2>',1)[1].split('</h2>',1)[0]
   Titulo.append(title)

  for i in range(0,len(Resultado)):  # Separando o título
    text = Resultado[i].split('</h2>',1)[1].split('</i></p>',1)[0].replace('</h1>','').replace('<br/>','').replace('<h1>','').replace('<br>','')
    Texto.append(text)

# %% [markdown]
# # Criando o banco de Dados Brutos

# %%
Titulo
# Out:
# ['INSTRUÇÃO NORMATIVA ANP Nº 9, DE 22 DE SETEMBRO DE 2021 - DOU DE 23.09.2021',
#  'INSTRUÇÃO NORMATIVA ANP Nº 8, DE 17 DE AGOSTO DE 2021. - DOU DE 19.08.2021',
#  'INSTRUÇÃO NORMATIVA ANP Nº 7, DE 16 DE JUNHO DE 2021- DOU DE 18.06.2021',
#  'INSTRUÇÃO NORMATIVA ANP Nº 6, DE 31 DE MAIO DE 2021- DOU DE 01.06.2021',
#  'INSTRUÇÃO NORMATIVA ANP Nº 5, DE 18 DE JANEIRO DE 2021- DOU DE 19 DE JANEIRO DE 2021',
#  'INSTRUÇÃO NORMATIVA ANP Nº 4, DE 3 DE NOVEMBRO DE 2020',
#  'INSTRUÇÃO NORMATIVA ANP Nº 3, DE 3 DE NOVEMBRO DE 2020',
#  'INSTRUÇÃO NORMATIVA ANP Nº 2, DE 11.02.2020, DOU 13 DE FEVEREIRO DE 2020',
#  'INSTRUÇÃO NORMATIVA ANP Nº 1, DE 31.01.2020, DOU 04 DE FEVEREIRO DE 2020',
#  'INSTRUÇÃO NORMATIVA SÉRIE GESTÃO INTERNA Nº 16/2019',
#  'INSTRUÇÃO NORMATIVA SÉRIE GESTÃO INTERNA Nº 15/2018',
#  'INSTRUÇÃO NORMATIVA SÉRIE GESTÃO INTERNA Nº 14/2018',
#  'INSTRUÇÃO NORMATIVA Nº 13/2017- DATA DE VIGÊNCIA 29/9/2017- APROVAÇÃO RD nº 584/2017',
#  'INSTRUÇÃO NORMATIVA Nº 12/2017 - DATA DA RD 10/5/2017 - APROVAÇÃO RESOLUÇÃO DE DIRETORIA (RD) Nº 282/2017',
#  'INSTRUÇÃO NORMATIVA SÉRIE GESTÃO INTERNA Nº 011/2016',
#  'INSTRUÇÃO NORMATIVA Nº 04/2016- DATA DE VIGÊNCIA 06/10/2016- APROVAÇÃO RD nº 807/2016',
#  'INSTRUÇÃO NORMATIVA Nº 3/2016, DATA DE VIGÊNCIA 8/2/2018- APROVAÇÃO RD Nº 82/2018',
#  'INSTRUÇÃO NORMATIVA Nº 2/2016, DATA DE VIGÊNCIA 4/2/2016- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 67/2016',
#  'INSTRUÇÃO NORMATIVA Nº 1/2015- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 169/2015',
#  'INSTRUÇÃO NORMATIVA Nº 10/2012, DATA DA VIGÊNCIA 01/02/2012- APROVAÇÃO RD Nº 63, DE 25 DE JANEIRO DE 2012',
#  'INSTRUÇÃO NORMATIVA Nº 1/2012, DATA DE VIGÊNCIA 07/11/2012 - APROVAÇÃO RD Nº 1.077/2012',
#  'INSTRUÇÃO NORMATIVA Nº 12/2011, DATA DE VIGÊNCIA 01/02/2012- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 1.187/2011',
#  'INSTRUÇÃO NORMATIVA Nº 12/2010- DATA DE VIGÊNCIA 23/02/2010, APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº RD Nº 135/2010',
#  'INSTRUÇÃO NORMATIVA Nº 1/2010',
#  'INSTRUÇÃO NORMATIVA Nº 11/2009, DATA DE VIGÊNCIA 14/04/2009- APROVAÇÃO RD Nº 340/2009 Nº 874/2010',
#  'INSTRUÇÃO NORMATIVA Nº 1/2009',
#  'INSTRUÇÃO NORMATIVA Nº 10/2008- DATA DE VIGÊNCIA 16/07/2008- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 491/2008',
#  'INSTRUÇÃO NORMATIVA Nº 9/2006- DATA DE VIGÊNCIA 09/08/2006- DATA DE VIGÊNCIA 09 DE AGOSTO DE 2006',
#  'INSTRUÇÃO NORMATIVA Nº 9, DE 16 DE FEVEREIRO DE 2004',
#  'INSTRUÇÃO NORMATIVA Nº 8/2004 - DATA DA VIGÊNCIA 20/02/2004 - 15/03/2011- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 6/2004 - 210/2011',
#  'INSTRUÇÃO NORMATIVA Nº 8/2002- DATA DE VIGÊNCIA 06/12/2002- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 816/2002',
#  'INSTRUÇÃO NORMATIVA Nº 5/2002- DATA DE VIGÊNCIA 09/07/2002- APROVAÇÃO RD Nº 477/2002',
#  'INSTRUÇÃO NORMATIVA Nº 7/2001- DATA DE VIGÊNCIA 27/11/2001- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 902/2001',
#  'INSTRUÇÃO NORMATIVA Nº 6/2001- DATA DE VIGÊNCIA 21/11/2001- 9/4/2014- APROVAÇÃO RD Nº 873/2001- RD Nº 342/2014',
#  'INSTRUÇÃO NORMATIVA Nº 5/2001 - DATA DE VIGÊNCIA 07/11/2001 - Aprovação Resolução de Diretoria nº 834/2001',
#  'INSTRUÇÃO NORMATIVA Nº 4/1999 - DATA DE VIGÊNCIA 13/12/2017 - APROVAÇÃO RD 745/2017',
#  'INSTRUÇÃO NORMATIVA SÉRIE GESTÃO INTERNA Nº 3/1999',
#  'INSTRUÇÃO NORMATIVA Nº 3/1999, DATA DE VIGÊNCIA 09/12/1999- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 616/99',
#  'INSTRUÇÃO NORMATIVA Nº 3/1999',
#  'INSTRUÇÃO NORMATIVA Nº 2/1999, DATA DE VIGÊNCIA 03/08/1999- APROVAÇÃO RESOLUÇÃO DE DIRETORIA Nº 242/99',
#  'INSTRUÇÃO NORMATIVA Nº 1/1999']

# %%
Titulo[i]
# Out:
# 'INSTRUÇÃO NORMATIVA ANP Nº 9, DE 22 DE SETEMBRO DE 2021 - DOU DE 23.09.2021'

# %%
Data_lei = [] # Pegando a data de publicação no DOU

for i in range(0,len(Titulo)):
    if 'DATA DE VIGÊNCIA' in str(Titulo[i]):
        ano = Titulo[i].split("DATA DE VIGÊNCIA")[1].split("-")[0].replace('DE','').replace(' ','').replace(',APROVAÇÃORESOLUÇÃODIRETORIANºRDNº135/2010',' ')
        Data_lei.append(ano)
    else:
        Data_lei.append(' ')
 
Data_lei
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '29/9/2017',
#  ' ',
#  ' ',
#  '06/10/2016',
#  '8/2/2018',
#  '4/2/2016',
#  ' ',
#  ' ',
#  '07/11/2012',
#  '01/02/2012',
#  '23/02/2010 ',
#  ' ',
#  '14/04/2009',
#  ' ',
#  '16/07/2008',
#  '09/08/2006',
#  ' ',
#  ' ',
#  '06/12/2002',
#  '09/07/2002',
#  '27/11/2001',
#  '21/11/2001',
#  '07/11/2001',
#  '13/12/2017',
#  ' ',
#  '09/12/1999',
#  ' ',
#  '03/08/1999',
#  ' ']

# %%
################################################ Criando o ID

Tipo = ['707']*len(Titulo) # Tipo de Lei

Num_lei = [] # Pegando o ano da lei

for i in range(0,len(Titulo)):
    if ', DE' not in str(Titulo[i]):
        Num_lei.append(Titulo[i].split('Nº ')[1].split('/')[0])
        
    elif ', DE' in str(Titulo[i]):
        Num_lei.append(Titulo[i].split('Nº ')[1].split(', DE')[0].replace('/2012, DATA DA VIGÊNCIA 01/02/2012- APROVAÇÃO RD ',''))

        
Ano_lei = [] # Pegando o ano da lei

for i in range(0,len(Titulo)):
    Ano_lei.append(Titulo[i][-4:].replace('6/99','1999').replace('2/99','1999'))

parte1 = [i + j for i, j in zip(Tipo, Num_lei)] # Juntado os valores
ID = [i + j for i, j in zip(parte1, Ano_lei)] 

################################################ Data_publicação

Data_DOU = [] # Pegando a data de publicação no DOU

for i in range(0,len(Titulo)):
    if 'DOU' in str(Titulo[i]):
        ano = Titulo[i].split("DOU")[1].replace('DE','').replace(' ','').replace('JANEIRO','.01.').replace('FEVEREIRO','.02.')
        Data_DOU.append(ano)
    else:
        Data_DOU.append(' ')

################################################ Data_lei

Data_lei = [] 

for i in range(0,len(Titulo)):
    if 'DATA DE VIGÊNCIA' in str(Titulo[i]):
        ano = Titulo[i].split("DATA DE VIGÊNCIA")[1].split("-")[0].replace('DE','').replace(' ','').replace(',APROVAÇÃORESOLUÇÃODIRETORIANºRDNº135/2010',' ')
        Data_lei.append(ano)
    else:
        Data_lei.append(' ')

################################################ Revogada

Resultado_revoga = []
for i in range(0,len(Link)):
  if 'Norma revogada' in Link[i]:
    result = True
    Resultado_revoga.append(result)
  else:
    result = False
    Resultado_revoga.append(result)




import pandas as pd

# Criando um DataFrame para alocar os outputs

dados = pd.DataFrame (ID ,columns=['ID'])
dados['Texto_lei'] = Texto
dados['Data_lei'] = Data_lei
dados['Data_publicação'] = Data_DOU
dados['Tipo_lei'] = Tipo
dados['Revogada'] = Resultado_revoga
dados['Setor'] = ['Anp']*len(Titulo)

dados
# Out:
#             ID                                          Texto_lei  \
# 0     70792021  Altera a Instrução Normativa nº <a class="link...
# 1     70782021  Disciplina os instrumentos de participação soc...
# 2     70772021  Dispõe sobre a utilização de Serviço Móvel Pes...
# 3     70762021  Estabelece o procedimento para a verificação d...
# 4     70752021  Estabelece critérios e procedimentos para mani...
# 5     70742020  Dispõe sobre o estabelecimento do Comando de I...
# 6     70732020  Regulamenta o processo decisório da Agência Na...
# 7     70722020  Estabelece o procedimento a ser adotado para a...
# 8     70712020  <b>(Vide Portaria ANP nº  <a class="link_law" ...
# 9    707162019  Aprovação RD nº 96/2019, de 31/1/2019Classific...
# 10   707152018  Aprovação RD nº 688/2018, de 08/11/2018Classif...
# 11   707142018  Número 14/2018Aprovação RD nº 156 /2018, de 20...
# 12   707132017  Procedimentos relativos a comitês, comissões e...
# 13   707122017  POLÍTICA DE SEGURANÇA DA INFORMAÇÃO E COMUNICA...
# 14  7070112016  Aprovação Resolução de Diretoria nº <a class="...
# 15   707042016  <b>(Revogada pela Portaria ANP nº  <a class="l...
# 16    70732018  PROCEDIMENTOS DE FISCALIZAÇÃO.1. OBJETIVO1.1. ...
# 17    70722016  LEILÕES DE BIODIESEL.1. OBJETIVO1.1. Disciplin...
# 18    70712015  Investigação de Incidentes Operacionais.1. OBJ...
# 19   707102012  Centro de Documentação e Informação1. DOS OBJE...
# 20    70712012  DEVOLUÇÃO DE PRAZOS EM RAZÃO DE ATRASO DO PROC...
# 21   707122011  UTILIZAÇÃ DE VAGAS DE GARAGEM.1. DO OBJETIVONo...
# 22   707122010  Normatização do processo de celebração e acomp...
# 23    70712010  OBJETIVOInstituir procedimento para análise da...
# 24   707112010  NORMATIZAÇÃO DOS CRITÉRIOS OPERACIONAIS PARA E...
# 25    70712009  <b>(Revogada pela Instrução Normativa nº <a cl...
# 26   707102008  <b>(Revogada pela Instrução Normativa nº <a cl...
# 27    70792006  NORMATIZAÇÃO DA DESCENTRALIZAÇÃO DE RECURSOS E...
# 28    70792004  <b>(Revogada pela Portaria ANP nº  <a class="l...
# 29    70782011  <b>(Revogada pela Instrução Normativa nº <a cl...
# 30    70782002  NORMATIZAÇÃO DA GESTÃO DE BENS MÓVEIS.1. OBJET...
# 31    70752002  Gestão de Documentos.1. OBJETIVODefinir as reg...
# 32    70772001  NORMATIZAR A UTILIZAÇÃO DO SERVIÇO DE REPROGRA...
# 33    70762014  NORMATIZAR A UTILIZAÇÃO DE VEÍCULOS OFICIAIS.1...
# 34    70752001  REQUISIÇÃO DE MATERIAL DE ALMOXARIFADO.1. DO O...
# 35    70742017  AQUISIÇÃO DE BENS E CONTRATAÇÃO DE OBRAS E SER...
# 36    70731999  <b>(Revogada pela Portaria ANP nº  <a class="l...
# 37    70731999  <b>(Revogada pela Portaria ANP nº  <a class="l...
# 38    70731999  VIAGENS A SERVIÇO.1. OBJETIVODisciplinar os pr...
# 39    70721999  <b>(Revogada pela Portaria ANP nº  <a class="l...
# 40    70711999  <b>(Revogada pela Instrução Normativa nº <a cl...
#
#        Data_lei Data_publicação Tipo_lei  Revogada Setor
# 0                    23.09.2021      707     False   Anp
# 1                    19.08.2021      707     False   Anp
# 2                    18.06.2021      707     False   Anp
# 3                    01.06.2021      707     False   Anp
# 4                    19.01.2021      707     False   Anp
# 5                                    707     False   Anp
# 6                                    707     False   Anp
# 7                    13.02.2020      707     False   Anp
# 8                    04.02.2020      707     False   Anp
# 9                                    707     False   Anp
# 10                                   707     False   Anp
# 11                                   707     False   Anp
# 12    29/9/2017                      707     False   Anp
# 13                                   707     False   Anp
# 14                                   707     False   Anp
# 15   06/10/2016                      707     False   Anp
# 16     8/2/2018                      707     False   Anp
# 17     4/2/2016                      707     False   Anp
# 18                                   707     False   Anp
# 19                                   707     False   Anp
# 20   07/11/2012                      707     False   Anp
# 21   01/02/2012                      707     False   Anp
# 22  23/02/2010                       707     False   Anp
# 23                                   707     False   Anp
# 24   14/04/2009                      707     False   Anp
# 25                                   707     False   Anp
# 26   16/07/2008                      707     False   Anp
# 27   09/08/2006                      707     False   Anp
# 28                                   707     False   Anp
# 29                                   707     False   Anp
# 30   06/12/2002                      707     False   Anp
# 31   09/07/2002                      707     False   Anp
# 32   27/11/2001                      707     False   Anp
# 33   21/11/2001                      707     False   Anp
# 34   07/11/2001                      707     False   Anp
# 35   13/12/2017                      707     False   Anp
# 36                                   707     False   Anp
# 37   09/12/1999                      707     False   Anp
# 38                                   707     False   Anp
# 39   03/08/1999                      707     False   Anp
# 40                                   707     False   Anp

# %%
dados.to_csv("Instrucao_normativa_ANP.txt", index=False, encoding='utf-8-sig', sep = '汉')
